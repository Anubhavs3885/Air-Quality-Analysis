# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Example dataset
data = pd.DataFrame({'Group1': [1, 2, 3, 4, np.nan, 6, 7],
                     'Group2': [2, 4, 6, 8, 10, 12, 14],
                     'Group3': [3, 6, 9, 12, 15, 18, 21]})

# Box plot
data_dropped_rows = data.dropna()
plt.figure(figsize=(10, 6))
plt.boxplot(data_dropped_rows)
plt.xlabel('Groups')
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
data1 = pd.DataFrame({
    'DateTime': pd.date_range(start='2022-01-01', end='2022-12-31', freq='15min'),
})
c=data.iloc[:-3,3]
q = [ [ None for i in range(5) ] for j in range(4) ]
col=[[c[j+(i*96)] for i in range(90)] for j in range(96)]
df=pd.DataFrame(data=col)

col_dropped=df.dropna()

# data_pivot = data.pivot_table(index=data1['DateTime'].dt.time, columns=data1['DateTime'].dt.date, values=col)
plt.figure(figsize=(10, 6))
plt.boxplot(col_dropped)
plt.xlabel('Date')
plt.ylabel('Observations')
plt.title('Box Plot of Observations vs. Time')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample time-series data with missing values
data=pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
c=data.iloc[:8640,3]
col=[[c[j+(i*96)] for i in range(90)] for j in range(96)]

time_index = pd.date_range(start='00:00', end='23:45', freq='15min')
time_col=pd.date_range(start='2023-02-01', end='2023-05-01', freq='D')
data1 = pd.DataFrame(data=col, index=time_index, columns=time_col)
print(data1.head())

# # Line plot
# plt.figure(figsize=(10, 6))
# plt.plot(data1.index, data1.data)
# plt.xlabel('Time')
# plt.ylabel('Sensor Values')
# plt.title('Time-Series Line Plot')
# plt.legend()
# plt.show()

# # Area plot
# plt.figure(figsize=(10, 6))
# plt.stackplot(data.index, data['sensor1'], data['sensor2'], data['sensor3'], labels=['Sensor 1', 'Sensor 2', 'Sensor 3'])
# plt.xlabel('Time')
# plt.ylabel('Sensor Values')
# plt.title('Time-Series Area Plot')
# plt.legend()
# plt.show()

# # Heatmap
# plt.figure(figsize=(10, 6))
# plt.imshow(data.T, cmap='hot', interpolation='nearest', aspect='auto')
# plt.colorbar()
# plt.xlabel('Time')
# plt.ylabel('Sensors')
# plt.title('Time-Series Heatmap')
# plt.xticks(ticks=np.arange(len(data.index)), labels=data.index.date, rotation=45)
# plt.yticks(ticks=np.arange(len(data.columns)), labels=data.columns)
# plt.tight_layout()
# plt.show()
# Out:
#                      2023-02-01  2023-02-02  2023-02-03  2023-02-04  \
# 2023-06-21 00:00:00        95.0       178.0       234.0       180.0
# 2023-06-21 00:15:00        95.0       178.0       234.0       180.0
# 2023-06-21 00:30:00        95.0       178.0       234.0       180.0
# 2023-06-21 00:45:00       122.0       146.0       158.0       216.0
# 2023-06-21 01:00:00       122.0       146.0       158.0       216.0
#
#                      2023-02-05  2023-02-06  2023-02-07  2023-02-08  \
# 2023-06-21 00:00:00       293.0       503.0       293.0       197.0
# 2023-06-21 00:15:00       293.0       503.0       293.0       197.0
# 2023-06-21 00:30:00       293.0       503.0       293.0       197.0
# 2023-06-21 00:45:00       307.0       554.0       364.0       157.0
# 2023-06-21 01:00:00       307.0       554.0       364.0       157.0
#
#                      2023-02-09  2023-02-10  ...  2023-04-22  2023-04-23  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
data = data.drop(data.index[-3:])
data['From'] = pd.to_datetime(data['From'])
data['From'] = data['From'].dt.round('15min')
data['From'] = data['From'].dt.time
# data_resampled = data.groupby('From')['Singrauli, Surya Kiran Bhawan Dudhichua  NH3 (µg/m3)'].mean()
data.boxplot(by='From', column=['Singrauli, Surya Kiran Bhawan Dudhichua  NH3 (µg/m3)'])
# Out:
# <Axes: title={'center': 'Singrauli, Surya Kiran Bhawan Dudhichua  NH3 (µg/m3)'}, xlabel='From'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
y1=data.iloc[:-3,3].interpolate(method='polynomial', order=5)
y2=data.iloc[:-3,4].interpolate(method='polynomial', order=7)
data.iloc[0,5]=0.1
data.iloc[0,9]=0.1
data.iloc[8639,8]=0.1
data.iloc[8639,9]=0.1
y3=data.iloc[:-3,5].interpolate(method='polynomial', order=7)
y4=data.iloc[:-3,6].interpolate(method='polynomial', order=7)
y5=data.iloc[:-3,7].interpolate(method='polynomial', order=7)
y6=data.iloc[:-3,8].interpolate(method='polynomial', order=7)
y7=data.iloc[:-3,9].interpolate(method='polynomial', order=7)
y8=data.iloc[:-3,10].interpolate(method='polynomial', order=7)
y9=data.iloc[:-3,11].interpolate(method='polynomial', order=5)
y10=data.iloc[:-3,12].interpolate(method='polynomial', order=5)

# %%
l1=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y1[j]
  l1.append(sum/90)
m1=np.mean(l1)

l2=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y2[j]
  l2.append(sum/90)
m2=np.mean(l2)

l3=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y3[j]
  l3.append(sum/90)
m3=np.mean(l3)

l4=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y4[j]
  l4.append(sum/90)
m4=np.mean(l4)

l5=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y5[j]
  l5.append(sum/90)
m5=np.mean(l5)

l6=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y6[j]
  l6.append(sum/90)
m6=np.mean(l6)

l7=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y7[j]
  l7.append(sum/90)
m7=np.mean(l7)

l8=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y8[j]
  l8.append(sum/90)
m8=np.mean(l8)

l9=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y9[j]
  l9.append(sum/90)
m9=np.mean(l9)

l10=[]
for i in range(0, 96):
  sum=0
  for j in range(i, 8640, 96):
    sum+=y10[j]
  l10.append(sum/90)
m10=np.mean(l10)

# %%
from scipy.stats import norm
import scipy
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
d = {'PM10': l1, 'PM2.5': l2, 'NO': l3, 'NO2': l4, 'NOX': l5, 'CO': l6, 'SO2': l7, 'NH3': l8, 'Ozone': l9, 'Benzene': l10}
df = pd.DataFrame(d)
scaler = MinMaxScaler()
df = scaler.fit_transform(df)
weights = np.ones(df.shape[1])
def optimize_weights(weights):
    combined_data = np.dot(df, weights)
    print(combined_data)
    _, qq = norm.fit(combined_data)  # Fit a normal distribution and obtain QQ plot  # Perform a normality test
    _, p_value = scipy.stats.normaltest(combined_data)
    return abs(qq) + p_value  # Objective function to minimize

# Optimize the weights to resemble a normal distribution in QQ plot
from scipy.optimize import minimize
result = minimize(optimize_weights, weights, method='Nelder-Mead')

optimized_weights = result.x
combined_data = np.dot(df, optimized_weights)
# combined_data = scaler.fit_transform(combined_data)

print(combined_data)
# Out:
# Streaming output truncated to the last 5000 lines.
#  3.3998207  3.34654995 3.27895062 3.30987228 3.32389581 3.33532777
#  3.34533242 3.35700641 3.36045575 3.36632892 3.36795132 3.36923346
#  3.36444375 3.35936226 3.3594798  3.36391524 3.36572429 3.36408902
#  3.36005418 3.35667389 3.3340624  3.32381383 3.31724651 3.31072587
#  3.31305628 3.32348187 3.33809066 3.33172435 3.34400962 3.3577258
#  3.37311408 3.35959551 3.36300143 3.3661363  3.36778553 3.38251004
#  3.38286643 3.38041385 3.38045588 3.38242787 3.37622988 3.37268449
#  3.37583847 3.3760907  3.3757711  3.37845597 3.38139332 3.38214992]
# [3.38326735 3.36729691 3.35466867 3.34107301 3.32961304 3.32458727
#  3.31867929 3.31667073 3.31015796 3.3067848  3.30268868 3.3024701
#  3.29922349 3.29781373 3.29586313 3.29697826 3.294957   3.29751199
#  3.29684569 3.29946364 3.30306799 3.31135222 3.32541316 3.33148777
#  3.34548108 3.3608395  3.3829511  3.37140155 3.38417839 3.3909331
# ...

# %%
# plt.hist(combined_data, bins=1000)
# plt.xlabel('Combined Pollution Effect')
# plt.ylabel('Frequency')
# plt.title('Histogram of Combined Pollution Effect')
# plt.show()

plt.figure(figsize=(12, 6))
plt.plot(range(0,96), combined_data, color='blue', label='Combined Pollution Index')
# plt.plot(threshold_line_x, threshold_line_y, color='red', linestyle='-', label='Threshold Line')
plt.xlabel('Date')
plt.ylabel('Combined Pollution Index')
plt.title('Time Series Data with Zigzag Threshold Line')
plt.legend()
plt.show()

import statsmodels.api as sm
plt.figure(figsize=(6, 6))
fig, ax=plt.subplots()
sm.qqplot(combined_data, line='s', ax=ax)
ax.set_title('Pollution Effect')
plt.show()

# %%
print(type(combined_data))
# Out:
# <class 'numpy.ndarray'>

# %%
m = m1 + m2 + m3 + m6 + m7 + m8 + m9 + m10 + m4 + m5
print(m)
# Out:
# -16460393719768.795

# %%
lf=[]
for i in range(0,96):
  lf.append((l1[i]*(m1/m))+(l2[i]*(m2/m))+(l3[i]*(m3/m))+(l4[i]*(m4/m))+(l5[i]*(m5/m))+(l6[i]*(m6/m))+(l7[i]*(m7/m))+(l8[i]*(m8/m))+(l9[i]*(m9/m))+(l10[i]*(m10/m)))
print(lf)
# Out:
# [-34858699397329.77, -34971841218587.71, -35081719011639.45, -35188365694641.484, -35291813961364.9, -35392096282306.85, -35489244905797.3, -35583291859102.625, -35674268949525.8, -35762207765500.08, -35847139677679.43, -35929095840029.15, -36008107190909.56, -36084204454153.29, -36157418140142.47, -36227778546882.414, -36295315761069.57, -36360059659155.84, -36422039908410.54, -36481285967976.26, -36537827089922.12, -36591692320297.16, -36642910500169.87, -36691510266675.555, -36737520054053.38, -36780968094681.6, -36821882420107.17, -36860290862074.08, -36896221053548.39, -36929700429736.64, -36960756229100.734, -36989415494375.78, -37015705073580.266, -37039651621003.805, -37061281598234.734, -37080621275142.195, -37097696730874.734, -37112533854851.82, -37125158347750.66, -37135595722489.59, -37143871305211.336, -37150010236269.28, -37154037471156.52, -37155977781532.68, -37155855756188.5, -37153695801964.23, -37149522144711.95, -37143358830278.43, -37135229725471.44, -3712515851
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(data.iloc[:96,1], l1, 'b-', linewidth=2)
plt.title('PM10 (polynomial interploation degree 5)')
plt.show()
plt.plot(data.iloc[:96,1], l2, 'b-', linewidth=2)
plt.title('PM2.5 (polynomial interploation degree 7)')
plt.show()
plt.plot(data.iloc[:96,1], l3, 'b-', linewidth=2)
plt.title('NO (polynomial interploation degree 7)')
plt.show()
plt.plot(data.iloc[:96,1], l4, 'b-', linewidth=2)
plt.title('NO2 (polynomial interploation degree 7)')
plt.show()
plt.plot(data.iloc[:96,1], l5, 'b-', linewidth=2)
plt.title('NOX (polynomial interploation degree 7)')
plt.show()
plt.plot(data.iloc[:96,1], l6, 'b-', linewidth=2)
plt.title('CO (polynomial interploation degree 7)')
plt.show()
plt.plot(data.iloc[:96,1], l7, 'b-', linewidth=2)
plt.title('SO2 (polynomial interploation degree 7)')
plt.show()
plt.plot(data.iloc[:96,1], l8, 'b-', linewidth=2)
plt.title('NH3 (polynomial interploation degree 7)')
plt.show()
plt.plot(data.iloc[:96,1], l9, 'b-', linewidth=2)
plt.title('Ozone (polynomial interploation degree 7)')
plt.show()
plt.plot(data.iloc[:96,1], l10, 'b-', linewidth=2)
plt.title('Benzene (polynomial interploation degree 7)')
plt.show()

# %%
plt.plot(data.iloc[:96,1], combined_data, 'b-', linewidth=2)
plt.title('Benzene (polynomial interploation degree 7)')
plt.show()

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
l1 = np.array(l1)
l2 = np.array(l2)
l3 = np.array(l3)
l6 = np.array(l6)
l7 = np.array(l7)
l8 = np.array(l8)
l9 = np.array(l9)
l10 = np.array(l10)
lf = np.array(lf)
# or Convert the list to a Pandas Series
# my_series = pd.Series(my_list)

sm.qqplot(l1, line='s')  # 's' for standardized line
plt.show()

sm.qqplot(l2, line='s')  # 's' for standardized line
plt.show()

sm.qqplot(l3, line='s')  # 's' for standardized line
plt.show()

sm.qqplot(l6, line='s')  # 's' for standardized line
plt.show()

sm.qqplot(l7, line='s')  # 's' for standardized line
plt.show()

sm.qqplot(l8, line='s')  # 's' for standardized line
plt.show()

sm.qqplot(l9, line='s')  # 's' for standardized line
plt.show()

sm.qqplot(l10, line='s')  # 's' for standardized line
plt.show()

sm.qqplot(lf, line='s')  # 's' for standardized line
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
data = data.drop(data.index[-3:])
data['From'] = pd.to_datetime(data['From'])
data['From'] = data['From'].dt.time
data.boxplot(by='From', column=['Singrauli, Surya Kiran Bhawan Dudhichua  NH3 (µg/m3)'])
# Out:
# <Axes: title={'center': 'Singrauli, Surya Kiran Bhawan Dudhichua  NH3 (µg/m3)'}, xlabel='From'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrame with datetime values
data = pd.DataFrame({
    'Date': pd.date_range(start='2023-01-01', end='2023-01-20', freq='D'),
    'Value': [5, 8, 12, 10, 15, 18, 20, 25, 22, 30, 28, 35, 32, 40, 38, 45, 42, 50, 48, 55]
})

# Set the 'Date' column as the index
data.set_index('Date', inplace=True)

# Plot the linear time series
data.plot()

# Set labels and title
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Linear Time Series')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
data = data.drop(data.index[-3:])
data=data.fillna(data.mean())
data['From'] = pd.to_datetime(data['From'])
data.set_index('From', inplace=True)
# data['Singrauli, Surya Kiran Bhawan Dudhichua  NH3 (µg/m3)'].plot()
data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'].plot()
# data['Singrauli, Surya Kiran Bhawan Dudhichua  PM2.5 (µg/m3)'].plot()
# data['Singrauli, Surya Kiran Bhawan Dudhichua  NO (µg/m3)'].plot()
# data['Singrauli, Surya Kiran Bhawan Dudhichua  NO2 (µg/m3)'].plot()
# data['Singrauli, Surya Kiran Bhawan Dudhichua  NOX (ppb)'].plot()
# data['Singrauli, Surya Kiran Bhawan Dudhichua  CO (mg/m3)'].plot()
# data['Singrauli, Surya Kiran Bhawan Dudhichua  SO2 (µg/m3)'].plot()
# data['Singrauli, Surya Kiran Bhawan Dudhichua  Ozone (µg/m3)'].plot()
# data['Singrauli, Surya Kiran Bhawan Dudhichua  Benzene (µg/m3)'].plot()
plt.legend()
plt.xlabel('Time')
plt.show()
# Out:
# <ipython-input-27-17e9ce44a058>:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=data.fillna(data.mean())

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
data=pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
data = data.drop(data.index[-3:])
data=data.fillna(data.median())
data['From'] = pd.to_datetime(data['From'])
data['From'] = data['From'].dt.round('H')
data['From'] = data['From'].dt.time
data_resampled = data.groupby('From')['Singrauli, Surya Kiran Bhawan Dudhichua  Benzene (µg/m3)'].mean()
data.boxplot(by='From', column=['Singrauli, Surya Kiran Bhawan Dudhichua  Benzene (µg/m3)'])
# Out:
# <ipython-input-28-6778dba56de0>:7: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=data.fillna(data.median())
# <Axes: title={'center': 'Singrauli, Surya Kiran Bhawan Dudhichua  Benzene (µg/m3)'}, xlabel='From'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import statsmodels.api as sm

# Load the dataset
data=pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')

data = data.drop(data.index[-3:])
# data1 = data.drop(data.columns[3:])
data['From'] = pd.to_datetime(data['From'])
data['From'] = data['From'].dt.round('H')
data['From'] = data['From'].dt.time

# Iterate over each column
for column in data.columns:
    # Extract the column data
    column_data = data[column]

    # Fit ARMA model
    model = sm.tsa.ARMA(column_data, order=(1,1))  # Replace p and q with desired ARMA order

    # Fit the model
    model_fit = model.fit()

    # Print the summary
    print(f"Column: {column}")
    print(model_fit.summary())
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-cbdaeb050afc> in <cell line: 17>()
#      20
#      21     # Fit ARMA model
# ---> 22     model = sm.tsa.ARMA(column_data, order=(1,1))  # Replace p and q with desired ARMA order
#      23
#      24     # Fit the model
#
# AttributeError: module 'statsmodels.tsa.api' has no attribute 'ARMA'

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.stattools import acf
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
ar1 = np.array([1, 0.33, 0.5])
ma1 = np.array([1, 0.9, 0.3])
simulated_ARMA_data = ArmaProcess(ar1, ma1).generate_sample(nsample=10000)

# %%
plt.figure(figsize=[15, 7.5]);
plt.plot(simulated_ARMA_data)
plt.title("Simulated ARMA(1,1) Process")
plt.xlim([0, 200])
plt.show()

# %%
plot_pacf(simulated_ARMA_data);
plot_acf(simulated_ARMA_data);

# %% [markdown]
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# data = pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
# data = data.drop(data.index[-3:])
# data['From'] = pd.to_datetime(data['From'])
# data['From'] = data['From'].dt.time
# r=[i for i in range(8640)]
# # Plot a linear plot
# sns.lmplot(x=r, y='Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)', data=data)
#
# # Set labels and title
# plt.xlabel('Time')
# plt.ylabel('PM10 (µg/m3)')
# plt.title('Linear Plot of PM10 by Time')
#
# # Rotate x-axis labels for better visibility (optional)
# plt.xticks(rotation=45)
#
# # Show the plot
# plt.show()

# %%
data=pd.read_csv('Open pit blasting 01-02-2023 000000 To 01-05-2023 235959.csv')
data=data.fillna(data.mean())
data.head()
# Out:
#    #                 From   To (Interval: 15M)  \
# 0  1  2023-02-01 00:00:00  2023-02-01 00:15:00
# 1  2  2023-02-01 00:15:00  2023-02-01 00:30:00
# 2  3  2023-02-01 00:30:00  2023-02-01 00:45:00
# 3  4  2023-02-01 00:45:00  2023-02-01 01:00:00
# 4  5  2023-02-01 01:00:00  2023-02-01 01:15:00
#
#    Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)  \
# 0                                               95.0
# 1                                               95.0
# 2                                               95.0
# 3                                              122.0
# 4                                              122.0
#
#    Singrauli, Surya Kiran Bhawan Dudhichua  PM2.5 (µg/m3)  \
# 0                                               35.0
# 1                                               35.0
# 2                                               35.0
# 3                                               34.0
# 4                                               34.0
#
# ...

# %%
plt.figure(figsize=[15, 7.5]); # Set dimensions for figure
plt.scatter(data['From'], data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'])
# plt.title('Quarterly EPS for Johnson & Johnson')
plt.ylabel('Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)')
plt.xlabel('Date')
# plt.xticks(rotation=90)
# plt.grid(True)
plt.show()

# %%
plot_pacf(data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)']);
plot_acf(data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)']);

# %%
# Augmented Dickey-Fuller test
ad_fuller_result = adfuller(data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'])
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -9.271489340273863
# p-value: 1.323126731075347e-15

# %%
# Take the log difference to make data stationary
data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'] = np.log(data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'])
data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'] = data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'].diff()
data = data.drop(data.index[0])
data.head()
# Out:
#    #                 From   To (Interval: 15M)  \
# 1  2  2023-02-01 00:15:00  2023-02-01 00:30:00
# 2  3  2023-02-01 00:30:00  2023-02-01 00:45:00
# 3  4  2023-02-01 00:45:00  2023-02-01 01:00:00
# 4  5  2023-02-01 01:00:00  2023-02-01 01:15:00
# 5  6  2023-02-01 01:15:00  2023-02-01 01:30:00
#
#    Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)  \
# 1                                           0.000000
# 2                                           0.000000
# 3                                           0.250144
# 4                                           0.000000
# 5                                           0.000000
#
#    Singrauli, Surya Kiran Bhawan Dudhichua  PM2.5 (µg/m3)  \
# 1                                               35.0
# 2                                               35.0
# 3                                               34.0
# 4                                               34.0
# 5                                               34.0
#
# ...

# %%
plt.figure(figsize=[15, 7.5]); # Set dimensions for figure
plt.plot(data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'])
plt.title("Log Difference of Quarterly EPS for Johnson & Johnson")
plt.show()

# %%
# Augmented Dickey-Fuller test
ad_fuller_result = adfuller(data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'])
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -23.417800084514756
# p-value: 0.0

# %%
plot_pacf(data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)']);
plot_acf(data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)']);

# %%
plt.figure(figsize=[15, 7.5]); # Set dimensions for figure
plt.scatter(data['From'], data['Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)'])
# plt.title('Quarterly EPS for Johnson & Johnson')
plt.ylabel('Singrauli, Surya Kiran Bhawan Dudhichua  PM10 (µg/m3)')
plt.xlabel('Date')
# plt.xticks(rotation=90)
# plt.grid(True)
plt.show()

# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
data = sm.datasets.co2.load_pandas()
y = data.data
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4
# ...           ...
# 2001-12-01  370.3
# 2001-12-08  370.8
# 2001-12-15  371.2
# 2001-12-22  371.3
# 2001-12-29  371.5
#
# [2284 rows x 1 columns]

# %%
# The 'MS' string groups the data in buckets by start of the month
y = y['co2'].resample('MS').mean()

# The term bfill means that we use the value before filling in missing values
y = y.fillna(y.bfill())

print(y)
# Out:
# 1958-03-01    316.100000
# 1958-04-01    317.200000
# 1958-05-01    317.433333
# 1958-06-01    315.625000
# 1958-07-01    315.625000
#                  ...
# 2001-08-01    369.425000
# 2001-09-01    367.880000
# 2001-10-01    368.050000
# 2001-11-01    369.375000
# 2001-12-01    371.020000
# Freq: MS, Name: co2, Length: 526, dtype: float64

# %%
y.plot(figsize=(15, 6))
plt.show()

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:7612.583429881011
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:6787.34362404079
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:1854.8282341411787
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:1596.7111727636975
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1058.938892132007
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1056.2878382366332
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:1361.657897807711
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:1044.7647912841048
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:6881.048755640422
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:6072.662327706686
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:1379.1941067057987
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:1241.4174716833727
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1111.7818109833097
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:801.4642720185643
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:1119.5957893610284
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:807.09129881839
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1675.8086923024289
# ...

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3182      0.092      3.441      0.001       0.137       0.499
# ma.L1         -0.6254      0.077     -8.162      0.000      -0.776      -0.475
# ar.S.L12       0.0010      0.001      1.732      0.083      -0.000       0.002
# ma.S.L12      -0.8769      0.026    -33.811      0.000      -0.928      -0.826
# sigma2         0.0972      0.004     22.632      0.000       0.089       0.106
# ...

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('1998-01-01'), dynamic=False)
pred_ci = pred.conf_int()

# %%
ax = y['1990':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('CO2 Levels')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['1998-01-01':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 0.07

# %%
pred_dynamic = results.get_prediction(start=pd.to_datetime('1998-01-01'), dynamic=True, full_results=True)
pred_dynamic_ci = pred_dynamic.conf_int()

# %%
ax = y['1990':].plot(label='observed', figsize=(20, 15))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_ci.index,
                pred_dynamic_ci.iloc[:, 0],
                pred_dynamic_ci.iloc[:, 1], color='k', alpha=.25)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('1998-01-01'), y.index[-1],
                 alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('CO2 Levels')

plt.legend()
plt.show()

# %%
# Extract the predicted and true values of our time series
y_forecasted = pred_dynamic.predicted_mean
y_truth = y['1998-01-01':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 1.01

# %%
# Get forecast 500 steps ahead in future
pred_uc = results.get_forecast(steps=500)

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

# %%
ax = y.plot(label='observed', figsize=(20, 15))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('CO2 Levels')

plt.legend()
plt.show()
